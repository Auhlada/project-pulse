# %% [markdown]
# # Project Pulse
#
# ## Notebook
# 01 - Data Loading

# %% [markdown]
# ## Goal
# Load the exported YouTube Studio dataset into Python and understand its structure.

# %% [markdown]
# ## Author
# Auhlada Sree Vyshnavi

# %% [markdown]
# ## Date
# 30 June 2026

# %%
import pandas as pd

# Display all columns during data exploration.
# By default, Pandas hides middle columns with "..." for wide DataFrames.
pd.set_option('display.max_columns', None) #pd.set_option('display.max_rows', None) - for rows, not practical on high volume data

# %%
# Load raw YouTube export into a DataFrame
df = pd.read_csv("../data/raw/table_data.csv")

# %%
df.head() #df.tail() - for last 5 rows, df.tail(x)/df.head(x)-display x number of rows, DEFAULT=5
# Out:
#        Content                                        Video title  \
# 1  VE6EZGr29NA                                  Chikiri 👌 Lyrics💀
# 2  H6yMF28ZyQk                           IBOMMA RAVI Case Solved!
# 3  irfyNRSMh88                                         ME IN 2025
# 4  NA2ZvoTvR6c  If you can survive this, you can survive anyth...
# 5  38KNroE0RcI                Daddy covering after hurting MOM 😅😂
#
#   Video publish time  Duration  Subscribers gained  Subscribers lost  Likes  \
# 1       Nov 11, 2025      16.0                 562                82  15593
# 2       Nov 19, 2025       6.0                  41                14   2365
# 3        Dec 3, 2025      12.0                  10                 0    141
# 4       Dec 22, 2025       8.0                   6                 0    236
# 5        Dec 2, 2025      35.0                   5                 0     55
#
#    Dislikes  Likes (vs dislikes) (%)  Shares  Comments added  Remix count  \
# ...

# %%
# Removed the summary row ('Total') because each row in our ML dataset should represent exactly one YouTube Short.
df = df[df["Content"] != "Total"]
#df.head()-check updated DF

# %%
df.shape
# Out:
# (60, 31)

# %%
df.columns
# Out:
# Index(['Content', 'Video title', 'Video publish time', 'Duration',
#        'Subscribers gained', 'Subscribers lost', 'Likes', 'Dislikes',
#        'Likes (vs dislikes) (%)', 'Shares', 'Comments added', 'Remix count',
#        'Remix views', 'Engaged views', 'Average view duration',
#        'Average percentage viewed (%)', 'Stayed to watch (%)',
#        'Unique viewers', 'Unique reach', 'Average views per viewer',
#        'New viewers', 'Returning viewers', 'Casual viewers', 'Regular viewers',
#        'Hypes', 'Hype points', 'Views', 'Watch time (hours)', 'Subscribers',
#        'Impressions', 'Impressions click-through rate (%)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Content                                object
# Video title                            object
# Video publish time                     object
# Duration                              float64
# Subscribers gained                      int64
# Subscribers lost                        int64
# Likes                                   int64
# Dislikes                                int64
# Likes (vs dislikes) (%)               float64
# Shares                                  int64
# Comments added                          int64
# Remix count                           float64
# Remix views                           float64
# Engaged views                           int64
# Average view duration                  object
# Average percentage viewed (%)         float64
# Stayed to watch (%)                   float64
# Unique viewers                        float64
# Unique reach                            int64
# Average views per viewer              float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Content                             61 non-null     object
#  1   Video title                         60 non-null     object
#  2   Video publish time                  60 non-null     object
#  3   Duration                            60 non-null     float64
#  4   Subscribers gained                  61 non-null     int64
#  5   Subscribers lost                    61 non-null     int64
#  6   Likes                               61 non-null     int64
#  7   Dislikes                            61 non-null     int64
#  8   Likes (vs dislikes) (%)             61 non-null     float64
#  9   Shares                              61 non-null     int64
#  10  Comments added                      61 non-null     int64
# ...
